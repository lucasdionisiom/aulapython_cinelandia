# %%
import pandas as pd
import numpy as np

# %%
## 📥 2. Carregamento dos Dados

try:
    # Carregando o arquivo diretamente do link
    # O arquivo utiliza ';' como separador (sep=';') e a codificação 'latin1'
    dfrm = pd.read_csv('BaseMunicipioMensal.csv',sep=';')
    print("✅ Dados carregados com sucesso!")
    display(dfrm)
    

except Exception as e:
    # Captura outros erros além de FileNotFoundError, como problemas de conexão ou formatação
    print(f"❌ Erro ao carregar o arquivo: {e}")
# Out:
# ❌ Erro ao carregar o arquivo: 'utf-8' codec can't decode byte 0xe9 in position 1145: invalid continuation byte
